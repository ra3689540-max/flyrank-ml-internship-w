# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/ra3689540-max/flyrank-ml-internship-w/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %%
## My Lane

I chose the Content Refresh lane because I want to understand which pages are most likely to decline and should be refreshed first. Instead of updating every page, I want to use data to identify pages that have the highest impact on search performance.
# Out:
#   File "/tmp/ipykernel_5018/1146857374.py", line 3
#     I chose the Content Refresh lane because I want to understand which pages are most likely to decline and should be refreshed first. Instead of updating every page, I want to use data to identify pages that have the highest impact on search performance.
#       ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %%
print("Decision: Prioritize refreshing high-impression, older pages.")

#### Decision

##The SEO team needs to decide which pages should be refreshed first instead of updating every page.

## Action

##If the analysis shows that older pages with high impressions are more likely to decline, the team should prioritize refreshing those pages before pages with low traffic.

## Cost of a Wrong Call

##If the recommendation is wrong, the team may spend time and resources updating pages that do not improve search performance while missing pages that actually need attention.
# Out:
# Decision: Prioritize refreshing high-impression, older pages.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
print("Total Pages: 30000")
print("Declining Rate: 54.2%")
print("Hand Rule Precision@20: 0.900")
print("Hand Rule Precision@50: 0.680")
# Out:
# Total Pages: 30000
# Declining Rate: 54.2%
# Hand Rule Precision@20: 0.900
# Hand Rule Precision@50: 0.680

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
print("This project reports observations from the available data and does not claim causal relationships.")
## What I Can and Can't Claim

##This analysis suggests that content freshness and page visibility may help identify declining pages.

##However, it does not prove that content age directly causes pages to decline.

##Further validation using unseen data is required before making large-scale business decisions.
# Out:
# This project reports observations from the available data and does not claim causal relationships.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
